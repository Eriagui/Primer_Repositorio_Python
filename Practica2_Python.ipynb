# %% [markdown]
# <a href="https://colab.research.google.com/github/Eriagui/Primer_Repositorio_Python/blob/main/Practica2_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FUNDAMENTOS Y APLICACIONES DE INTELIGENCIA ARTIFICIAL

# %% [markdown]
# Universidad TecMilenio
#
# Erick Aguilar
#
# Actividad 4
#
# ---

# %%
#HOLA MUNDO
print ("hola mundo")
# Out:
# hola mundo
